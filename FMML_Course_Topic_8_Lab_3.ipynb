# %% [markdown]
# <a href="https://colab.research.google.com/github/Satish-30/FMML-LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 04:06:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   211MB/s    in 0.3s
#
# 2023-05-05 04:06:37 (211 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(10, 16))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=5000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21847   1401.2451v1  It is the main goal of this paper to propose a...  stat
# 6042   1606.04618v1  We consider the problem of selecting an optima...  stat
# 19928   1303.5417v1  Bayes nets are relatively recent innovations. ...    cs
# 17735  1802.05574v1  Open Information Extraction (OIE) is the task ...    cs
# 15929  1606.08425v3  The problem of accurately predicting relative ...    cs
# ...             ...                                                ...   ...
# 6030   1606.03439v1  Training energy-based probabilistic models is ...    cs
# 31532  1803.06131v1  Motivated by recent work on deep neural networ...    cs
# 18666   1108.2865v1  In this paper, we investigate the following qu...    cs
# 15388   1411.3561v1  The paper aims to show how an application can ...    cs
# 22378  1605.02190v1  Biological systems are often modelled at diffe...  stat
#
#                                                    title  year  \
# 21847  Online Matrix Completion Through Nuclear Norm ...  2014
# 6042              Masking Strategies for Image Manifolds  2016
# 19928               The Topological Fusion of Bayes Nets  2013
# 17735  Open Information Extraction on Scientific Text...  2018
# 15929  Predicting the Relative Difficulty of Single S...  2016
# ...                                                  ...   ...
# 6030   Deep Directed Generative Models with Energy-Ba...  2016
# 31532  Towards Image Understanding from Deep Compress...  2018
# 18666  Conscious Machines and Consciousness Oriented ...  2011
# 15388  A Text to Speech (TTS) System with English to ...  2014
# 22378  Matching models across abstraction levels with...  2016
#
#                                                 keywords
# 21847  [completion, motivated, applications, recommen...
# 6042   [selecting, preserves, manifolds, geometric, s...
# 19928  [relatively, innovations, theoretical, develop...
# 17735  [information, extraction, unsupervised, struct...
# 15929  [accurately, predicting, difficulty, sentences...
# ...                                                  ...
# 6030   [probabilistic, confronted, apparently, intrac...
# 31532  [motivated, compression, potential, improvemen...
# 18666  [investigate, following, conscious, motivation...
# 15388  [application, developed, application, pronounc...
# 22378  [biological, different, abstraction, depending...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21847    [completion, motivated, applications, recommen...
# 6042     [selecting, preserves, manifolds, geometric, s...
# 19928    [relatively, innovations, theoretical, develop...
# 17735    [information, extraction, unsupervised, struct...
# 15929    [accurately, predicting, difficulty, sentences...
#                                ...
# 10575    [disambiguation, associated, wikipedia, challe...
# 39455    [localization, environment, monocular, structu...
# 25127    [representation, retrieval, retrieval, challen...
# 1849     [embedding, knowledge, embedding, implementati...
# 2148     [relational, similarity, relational, framework...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8864 words.
# Out of those 4624 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5703b4ce-8d40-42b1-bf25-6e3d1e2db04f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5703b4ce-8d40-42b1-bf25-6e3d1e2db04f")) {                    Plotly.newPlot(                        "5703b4ce-8d40-42b1-bf25-6e3d1e2db04f",                        [{"x":["regularisation","displayed","incrementally","increases","simplicity","requiring","recommender","efficient","computations","localization","gradually","sequential","reconstruction","numerical","situation","essentially","performance","literature","motivated","preliminary","applications","extension","introduced","experiments","decomposition","ourselves","theoretical","completion","computing","predictive","technique","precisely","illustrating","prediction","addressed","algorithm","randomised","counterpart","implements","approximated","selecting","compressive","platforms","respectively","accurately","strategies","structure","geometric","preserved","manifolds","dependent","preserves","expensive","computationally","compromises","questions","introduction","sophisticated","development","topological","introduces","compromise","innovations","posterior","relatively","difference","consensus","interesting","independent","primarily","originating","knowledge","including","downstream","available","structured","evaluated","significantly","sentences","extraction","judgments","evaluation","construction","unsupervised","scientific","newspaper","disciplines","different","information","answering","predicting","grammatical","differences","difficulty","estimating","assessing","introduce","conditions","surrounding","considering","challenges","important","generated","intelligent","contextual","regression","particularly","significant","attention","effective","aggregating","efficiency","principal","stochastic","component","randomized","algorithms","simulated","computational","approximately","sufficient","coordinates","partition","iteration","independently","initially","computers","iterations","probability","distributed","coordinate","described","minimization","partitioning","dictionary","continuous","framework","simultaneous","intervention","successive","representative","representation","eliminates","intrinsically","clustering","streaming","methodology","collaborative","boundaries","perspective","recognition","developed","classification","nevertheless","improvements","communities","eigenvectors","blockmodel","eigenvalues","demonstrate","difficult","analyzing","perturbations","interaction","scenarios","perturbation","classical","unperturbed","tractable","heuristic","approximate","distribution","tractability","establish","maintaining","dramatically","empirical","promoting","benchmark","encompass","adequately","regularization","functions","techniques","extensive","surprisingly","frobenius","compression","approaches","wikipedia","generalization","characteristic","increasingly","dirichlet","inference","automatically","hierarchical","meaningful","solutions","identical"],"y":[2,7,5,60,20,49,23,410,28,54,14,73,97,67,30,29,894,130,58,57,428,68,144,624,69,0,160,25,141,45,240,14,3,198,28,860,2,15,15,24,44,15,26,77,54,91,367,70,12,20,70,17,65,89,2,69,34,33,112,30,75,8,5,29,53,62,19,73,110,13,7,373,253,13,299,106,163,262,80,129,15,269,70,151,31,3,6,781,700,46,76,14,65,41,69,18,314,152,15,75,112,389,167,65,43,115,80,221,167,255,12,145,31,110,99,30,624,67,278,35,73,20,34,35,38,15,20,35,166,101,26,67,64,12,56,104,533,29,14,10,36,338,9,7,145,12,54,40,39,63,346,215,512,19,123,18,7,0,3,537,146,59,19,73,89,12,98,0,33,59,108,188,9,46,40,24,159,6,183,2,6,73,209,387,143,33,7,50,423,20,115,32,43,23,211,189,123,49,160,18],"type":"bar"},{"x":["regularisation","displayed","incrementally","increases","simplicity","requiring","recommender", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4624,), (4624, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8216666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>Approach</span> <span style=''>for</span> <span style=''>Joint</span> <span style=''>Video</span> <span style=''>Frame</span> <span style=''>and</span> <span style=''>Reward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>in</span> <span style=''>Atari</span> <span style=''>Games</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4444444444444444);'>Reinforcement</span> <span style=''>learning</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concerned</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>reward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviour</span> <span style=''>policies</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.509090909090909);'>environments</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695654);'>initially</span> <span style=''>unknown</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444444);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>such</span> <span style=''>as</span> <span style=''>deep</span> <span style=''>Q</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>model</span> <span style=''>free</span> <span style=''>and</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>act</span> <span style='background-color:rgba(0, 255, 0, 0.43617021276595747);'>effectively</span> <span style=''>across</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.509090909090909);'>environments</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Atari</span> <span style=''>games</span> <span style=''>but</span> <span style=''>require</span> <span style=''>huge</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>data</span> <span style=''>Model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style=''>more</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>but</span> <span style=''>need</span> <span style=''>to</span> <span style=''>acquire</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.39439252336448605);'>knowledge</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.631578947368421);'>environment</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>take</span> <span style=''>a</span> <span style=''>step</span> <span style=''>towards</span> <span style=''>using</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.509090909090909);'>environments</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3040152963671128);'>dimensional</span> <span style=''>visual</span> <span style=''>state</span> <span style=''>space</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrating</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>poss ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Trend</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Filtering</span> <span style=''>on</span> <span style=''>Graphs</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalizing</span> <span style=''>the</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>trend</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>Kim</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2009)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Tibshirani</span> <span style=''>(2014)</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>to</span> <span style=''>graphs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Analogous</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>univariate</span> <span style=''>case</span> <span style=''>graph</span> <span style=''>trend</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>exhibits</span> <span style=''>a</span> <span style=''>level</span> <span style=''>of</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptivity</span> <span style=''>unmatched</span> <span style=''>by</span> <span style=''>the</span> <span style=''>usual</span> <span style=''>ell</span> <span style=''>2</span> <span style=''>based</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothers</span> <span style=''>It</span> <span style=''>is</span> <span style=''>also</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>is</span> <span style=''>readily</span> <span style=''>solved</span> <span style=''>(eg</span> <span style=''>by</span> <span style=''>fast</span> <span style=''>ADMM</span> <span style=''>or</span> <span style=''>Newton</span> <span style=''>algorithms)</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>merits</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>trend</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>through</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>theory</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Negative</span> <span style=''>Learning</span> <span style=''>Rates</span> <span style=''>and</span> <span style=''>P</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>of</span> <span style=''>training</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>approximator</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5228215767634855);'>regression</span> <span style=''>task</span> <span style=''>using</span> <span style=''>negative</span> <span style=''>examples</span> <span style=''>We</span> <span style=''>effect</span> <span style=''>this</span> <span style=''>training</span> <span style=''>using</span> <span style=''>negative</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>how</span> <span style=''>this</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>direct</span> <span style=''>policy</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444444);'>reinforcement</span> <span style=''>learning</span> <span style=''>setting</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>Mixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <br/><br/><span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>data</span> <span style=''>(Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models)</span> <span style=''>and</span> <span style=''>discrete</span> <span style=''>data</span> <span style=''>(Ising</span> <span style=''>models)</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>studied</span> <span style=''>there</span> <span style=''>is</span> <span style=''>little</span> <span style=''>work</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>linking</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>and</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>(mixed</span> <span style=''>data)</span> <span style=''>which</span> <span style=''>are</span> <span style=''>common</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>for</span> <span style=''>mixed</span> <span style=''>data</span> <span style=''>which</span> <span style=''>is</span> <span style=''>simple</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>be</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>yet</span> <span style=''>flexible</span> <span style=''>enough</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>all</span> <span style=''>possible</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>fitting</span> <span style=''>the</span> <span style=''>model</span> <span style=''>by</span> <span style=''>focusing</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>log</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>of</span> <span style=''>each</span> <span style=''>variable</span> <span style=''>given</span> <span style=''>the</span> <span style=''>rest</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>have</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>group</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>sparsity</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13335716839470863)
# 	processing (0.101894887379335)
# 	architecture (0.08687879871290669)
# 	knowledge (0.13335716839470863)
# 	segmentation (0.0697175545227029)
# 	information (0.2502681444404719)
# 	detection (0.12549159814086522)
# 	recognition (0.12370396853771898)
# 	different (0.27922774401144085)
# 	convolutional (0.13371469431533786)
#
# Some Statistics words are:
# 	algorithm (0.3939091362955567)
# 	estimation (0.16225661507738393)
# 	theoretical (0.1507738392411383)
# 	variables (0.1397903145282077)
# 	stochastic (0.13879181228157764)
# 	statistical (0.1602596105841238)
# 	dimensional (0.17024463305042437)
# 	distribution (0.17923115327009487)
# 	inference (0.20818771842236644)
# 	regression (0.1832251622566151)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f7d56793-d7d5-4ab4-b1e0-e2d67068f3a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7d56793-d7d5-4ab4-b1e0-e2d67068f3a7")) {                    Plotly.newPlot(                        "f7d56793-d7d5-4ab4-b1e0-e2d67068f3a7",                        [{"x":["regularisation","displayed","incrementally","increases","simplicity","requiring","recommender","efficient","computations","localization","gradually","sequential","reconstruction","numerical","situation","essentially","performance","literature","motivated","preliminary","applications","extension","introduced","experiments","decomposition","ourselves","theoretical","completion","computing","predictive","technique","precisely","illustrating","prediction","addressed","algorithm","randomised","counterpart","implements","approximated","selecting","compressive","platforms","respectively","accurately","strategies","structure","geometric","preserved","manifolds","dependent","preserves","expensive","computationally","compromises","questions","introduction","sophisticated","development","topological","introduces","compromise","innovations","posterior","relatively","difference","consensus","interesting","independent","primarily","originating","knowledge","including","downstream","available","structured","evaluated","significantly","sentences","extraction","judgments","evaluation","construction","unsupervised","scientific","newspaper","disciplines","different","information","answering","predicting","grammatical","differences","difficulty","estimating","assessing","introduce","conditions","surrounding","considering","challenges","important","generated","intelligent","contextual","regression","particularly","significant","attention","effective","aggregating","efficiency","principal","stochastic","component","randomized","algorithms","simulated","computational","approximately","sufficient","coordinates","partition","iteration","independently","initially","computers","iterations","probability","distributed","coordinate","described","minimization","partitioning","dictionary","continuous","framework","simultaneous","intervention","successive","representative","representation","eliminates","intrinsically","clustering","streaming","methodology","collaborative","boundaries","perspective","recognition","developed","classification","nevertheless","improvements","communities","eigenvectors","blockmodel","eigenvalues","demonstrate","difficult","analyzing","perturbations","interaction","scenarios","perturbation","classical","unperturbed","tractable","heuristic","approximate","distribution","tractability","establish","maintaining","dramatically","empirical","promoting","benchmark","encompass","adequately","regularization","functions","techniques","extensive","surprisingly","frobenius","compression","approaches","wikipedia","generalization","characteristic","increasingly","dirichlet","inference","automatically","hierarchical","meaningful","solutions","identical","thousands","generally","interests","organizations","designing","dedicated","supervision","deployment","technical","supporting","situations","semantics","interoperability","individual","management","finishing","behaviour","workflows","engineering","automatic","previously","potential","processes","connection","appropriate","objective","providing","gathering","generation","exploitation","currently","initiating","innovative","decisions","annotation","neglected","experience","highlight","constitute","understand","segmenting","frequently","consistent","something","understanding","underlying","encountered","annotator","difficulties","annotations","spontaneous","utilizing","organization","addressing","interactive","especially","ecosystem","heterogeneous","orga ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ourselves
# 	blockmodel
# 	unperturbed
# 	marginalize
# 	collinearity
# 	astronomical
# 	cubically
# 	invention
# 	penalised
# 	homomorphic
# 	diagonalise
# 	sustainability
# 	reparametrizations
# 	whitening
# 	substantive
# 	nonconvexity
# 	semiparametric
# 	elliptical
# 	memberships
# 	faithfulness
# Some words which never appear in Statistics papers:
# 	newspaper
# 	organizations
# 	interoperability
# 	neglected
# 	something
# 	spontaneous
# 	realizing
# 	contractions
# 	additions
# 	formations
# 	revisions
# 	peculiarities
# 	erroneous
# 	sarcastic
# 	sentiments
# 	certainty
# 	exchanging
# 	localizes
# 	epithelial
# 	prolonged

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0680493342332946e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
